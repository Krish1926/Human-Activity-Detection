# %%
# !git config --global user.name "Krish1926"
# !git config --global user.email "ksaikrishna1912@gmail.com"
# !git config --global user.password "Sai@4617152424"

# %%
token ='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'
username ='Krish1926'
repo='Human-Activity-Detection'

# %%
# !git clone https://{token}@github.com/{username}/{repo}
# Out:
# Cloning into 'Human-Activity-Detection'...
# remote: Enumerating objects: 14, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 14 (delta 4), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (14/14), 4.48 MiB | 11.00 MiB/s, done.
# Resolving deltas: 100% (4/4), done.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

human_fall = pd.read_csv('All Users Combined.csv')
human_fall
# Out:
#            AG-X       AG-Y      AG-Z     Acc-X     Acc-Y     Acc-Z  Gravity-X  \
# 0     -9.494311   5.423363  0.196757 -1.684995  0.401508  1.334339  -8.855526
# 1     -8.890651   2.520043  0.963310 -0.895032 -1.936677  1.436671  -8.399648
# 2     -5.632800   1.581015  0.230293  2.350318 -3.642859 -1.169414  -7.911231
# 3     -6.322698   6.228244 -0.756644  0.812825 -0.722664 -0.334024  -7.523226
# 4     -7.640211   4.862821  1.715490  0.349670 -0.468074 -0.378780  -6.921238
# ...         ...        ...       ...       ...       ...       ...        ...
# 94193  0.648145  14.641164  8.029972  3.124783  8.580249  1.343975   0.424226
# 94194  0.648145  14.641164  8.029972  3.124783  8.580249  1.343975   0.424226
# 94195  0.648145  14.641164  8.029972  3.124783  8.580249  1.343975   0.424226
# 94196  0.648145  14.641164  8.029972  3.124783  8.580249  1.343975   0.424226
# 94197  0.648145  14.641164  8.029972  3.124783  8.580249  1.343975   0.424226
#
# ...
